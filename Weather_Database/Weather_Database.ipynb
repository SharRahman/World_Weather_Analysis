# %%
# Import the dependencies 
import pandas as pd 
from citipy import citipy
import numpy as np 
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and lonitudes to a list 
coordinates = lat_lngs

# %%
# List for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities: 
        cities.append(city)
# Print the city count to comfirm sufficient count. 
len(cities)
# Out:
# 762

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters. 
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i > 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Prcessing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1

# Run an API request for each of the cities. 
    try:
        # Pare the JSOn and retrieve data. 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city. 
    except:
        print("City not found. Skipping....")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Prcessing Record 1 of Set 1 | pevek
# Prcessing Record 2 of Set 1 | atuona
# Prcessing Record 3 of Set 1 | tuktoyaktuk
# Prcessing Record 4 of Set 1 | mataura
# Prcessing Record 5 of Set 1 | hobart
# Prcessing Record 6 of Set 1 | hithadhoo
# Prcessing Record 7 of Set 1 | roald
# Prcessing Record 8 of Set 1 | nelson bay
# Prcessing Record 9 of Set 1 | basco
# Prcessing Record 10 of Set 1 | vaini
# Prcessing Record 11 of Set 1 | kasongo-lunda
# Prcessing Record 12 of Set 1 | georgetown
# Prcessing Record 13 of Set 1 | kysyl-syr
# Prcessing Record 14 of Set 1 | north bend
# Prcessing Record 15 of Set 1 | port alfred
# Prcessing Record 16 of Set 1 | ushuaia
# Prcessing Record 17 of Set 1 | tasiilaq
# Prcessing Record 18 of Set 1 | albany
# Prcessing Record 19 of Set 1 | butaritari
# Prcessing Record 20 of Set 1 | bethel
# Prcessing Record 21 of Set 1 | xining
# Prcessing Record 22 of Set 1 | puerto ayora
# Prcessing Record 23 of Set 1 | jamestown
# Prcessing Record 24 of Set 1 | nanakuli
# Prcessing Record 25 of Set 1 | new norfolk
# Prcessing Record 26 of Set 1 | port elizabeth
# Prcessing Record 27 of Set 1 | yellowknife
# Prcessing Record 28 of Set 1 | thompson
# Prcessing Record 29 of Set 1 | upernavik
# Prcessing Record 30 of Set 1 | sabang
# Prcessing Record 31 of Set 1 | taolanaro
# City not found. Skipping....
# Prcessing Record 32 of Set 1 | aswan
# Prcessing Record 33 of Set 1 | longyearbyen
# Prcessing Record 34 of Set 1 | hovd
# Prcessing Record 35 of Set 1 | moussoro
# Prcessing Record 36 of Set 1 | khatanga
# Prcessing Record 37 of Set 1 | monte azul
# Prcessing Record 38 of Set 1 | klaksvik
# Prcessing Record 39 of Set 1 | teguldet
# Prcessing Record 40 of Set 1 | sorland
# Prcessing Record 41 of Set 1 | rikitea
# Prcessing Record 42 of Set 1 | asau
# Prcessing Record 43 of Set 1 | castro
# Prcessing Record 44 of Set 1 | jabiru
# City not found. Skipping....
# Prcessing Record 45 of Set 1 | ilulissat
# Prcessing Record 46 of Set 1 | bambous virieux
# Prcessing Record 47 of Set 1 | hihifo
# City not found. Skipping....
# Prcessing Record 48 of Set 1 | gisborne
# Prcessing Record 49 of Set 1 | adrar
# Prcessing Record 50 of Set 1 | tabas
# Prcessing Record 51 of Set 1 | margate
# Prcessing Record 52 of Set 1 | ucluelet
# Prcessing Record 53 of Set 1 | tsiroanomandidy
# Prcessing Record 54 of Set 1 | hilo
# Prcessing Record 55 of Set 1 | harper
# Prcessing Record 56 of Set 1 | okhotsk
# Prcessing Record 57 of Set 1 | codrington
# Prcessing Record 58 of Set 1 | byron bay
# Prcessing Record 59 of Set 1 | arefu
# Prcessing Record 60 of Set 1 | meulaboh
# Prcessing Record 61 of Set 1 | kruisfontein
# Prcessing Record 62 of Set 1 | mount isa
# Prcessing Record 63 of Set 1 | vardo
# Prcessing Record 64 of Set 1 | lata
# Prcessing Record 65 of Set 1 | hermanus
# Prcessing Record 66 of Set 1 | arman
# Prcessing Record 67 of Set 1 | cape town
# Prcessing Record 68 of Set 1 | mumford
# Prcessing Record 69 of Set 1 | traian
# Prcessing Record 70 of Set 1 | avarua
# Prcessing Record 71 of Set 1 | hami
# Prcessing Record 72 of Set 1 | grand river south east
# City not found. Skipping....
# Prcessing Record 73 of Set 1 | kaitangata
# Prcessing Record 74 of Set 1 | mocambique
# City not found. Skipping....
# Prcessing Record 75 of Set 1 | bur gabo
# City not found. Skipping....
# Prcessing Record 76 of Set 1 | pilna
# Prcessing Record 77 of Set 1 | mansa
# Prcessing Record 78 of Set 1 | tarsus
# Prcessing Record 79 of Set 1 | damghan
# Prcessing Record 80 of Set 1 | batemans bay
# Prcessing Record 81 of Set 1 | seydi
# Prcessing Record 82 of Set 1 | ewa beach
# Prcessing Record 83 of Set 1 | seoul
# Prcessing Record 84 of Set 1 | cidreira
# Prcessing Record 85 of Set 1 | mathbaria
# Prcessing Record 86 of Set 1 | busselton
# Prcessing Record 87 of Set 1 | college
# Prcessing Record 88 of Set 1 | pampa
# Prcessing Record 89 of Set 1 | port hardy
# Prcessing Record 90 of Set 1 | lompoc
# Prcessing Record 91 of Set 1 | ancud
# Prcessing Record 92 of Set 1 | klyuchi
# Prcessing Record 93 of Set 1 | malakal
# Prcessing Record 94 of Set 1 | umm lajj
# Prcessing Record 95 of Set 1 | yorosso
# Prcessing Record 96 of Set 1 | merrill
# Prcessing Record 97 of Set 1 | bluff
# Prcessing Record 98 of Set 1 | rylsk
# Prcessing Record 99 of Set 1 | saskylakh
# Prcessing Record 100 of Set 1 | vaitape
# Prcessing Record 1 of Set 2 | punta arenas
# Prcessing Record 2 of Set 2 | jawad
# Prcessing Record 3 of Set 2 | meyungs
# City not found. Skipping....
# Prcessing Record 4 of Set 2 | vila velha
# Prcessing Record 5 of Set 2 | cap malheureux
# Prcessing Record 6 of Set 2 | the valley
# Prcessing Record 7 of Set 2 | chokurdakh
# Prcessing Record 8 of Set 2 | abu dhabi
# Prcessing Record 9 of Set 2 | vila franca do campo
# Prcessing Record 10 of Set 2 | newtownards
# Prcessing Record 11 of Set 2 | sao filipe
# Prcessing Record 12 of Set 2 | mar del plata
# Prcessing Record 13 of Set 2 | minudasht
# Prcessing Record 14 of Set 2 | san patricio
# Prcessing Record 15 of Set 2 | cheyenne
# Prcessing Record 16 of Set 2 | pitimbu
# Prcessing Record 17 of Set 2 | bahir dar
# Prcessing Record 18 of Set 2 | bacuit
# City not found. Skipping....
# Prcessing Record 19 of Set 2 | yulara
# Prcessing Record 20 of Set 2 | torbay
# Prcessing Record 21 of Set 2 | jardim
# Prcessing Record 22 of Set 2 | plouzane
# Prcessing Record 23 of Set 2 | salym
# Prcessing Record 24 of Set 2 | palamos
# Prcessing Record 25 of Set 2 | beyneu
# Prcessing Record 26 of Set 2 | talcahuano
# Prcessing Record 27 of Set 2 | yeppoon
# Prcessing Record 28 of Set 2 | ternate
# Prcessing Record 29 of Set 2 | dingle
# Prcessing Record 30 of Set 2 | vestmanna
# Prcessing Record 31 of Set 2 | kavieng
# Prcessing Record 32 of Set 2 | tazovskiy
# Prcessing Record 33 of Set 2 | emerald
# Prcessing Record 34 of Set 2 | wattegama
# Prcessing Record 35 of Set 2 | ribeira grande
# Prcessing Record 36 of Set 2 | half moon bay
# Prcessing Record 37 of Set 2 | tommot
# Prcessing Record 38 of Set 2 | carnarvon
# Prcessing Record 39 of Set 2 | tuatapere
# Prcessing Record 40 of Set 2 | atikokan
# Prcessing Record 41 of Set 2 | cervo
# Prcessing Record 42 of Set 2 | kapaa
# Prcessing Record 43 of Set 2 | nassjo
# Prcessing Record 44 of Set 2 | stromness
# Prcessing Record 45 of Set 2 | manokwari
# Prcessing Record 46 of Set 2 | nanortalik
# Prcessing Record 47 of Set 2 | pacific grove
# Prcessing Record 48 of Set 2 | afmadu
# City not found. Skipping....
# Prcessing Record 49 of Set 2 | kibungo
# Prcessing Record 50 of Set 2 | coquimbo
# Prcessing Record 1 of Set 3 | samusu
# City not found. Skipping....
# Prcessing Record 2 of Set 3 | arraial do cabo
# Prcessing Record 3 of Set 3 | cherskiy
# Prcessing Record 4 of Set 3 | belushya guba
# City not found. Skipping....
# Prcessing Record 5 of Set 3 | salalah
# Prcessing Record 6 of Set 3 | lebu
# Prcessing Record 7 of Set 3 | kuusamo
# Prcessing Record 8 of Set 3 | urumqi
# Prcessing Record 9 of Set 3 | madona
# Prcessing Record 10 of Set 3 | sande
# Prcessing Record 11 of Set 3 | fortuna
# Prcessing Record 12 of Set 3 | marcona
# City not found. Skipping....
# Prcessing Record 13 of Set 3 | hofn
# Prcessing Record 14 of Set 3 | saint-augustin
# Prcessing Record 15 of Set 3 | miranda
# Prcessing Record 16 of Set 3 | oistins
# Prcessing Record 17 of Set 3 | borogontsy
# Prcessing Record 18 of Set 3 | vaitupu
# City not found. Skipping....
# Prcessing Record 19 of Set 3 | mapimi
# Prcessing Record 20 of Set 3 | havelock
# Prcessing Record 21 of Set 3 | barentsburg
# City not found. Skipping....
# Prcessing Record 22 of Set 3 | barrow
# Prcessing Record 23 of Set 3 | cabo san lucas
# Prcessing Record 24 of Set 3 | linden
# Prcessing Record 25 of Set 3 | fairbanks
# Prcessing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping....
# Prcessing Record 27 of Set 3 | nikolskoye
# Prcessing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping....
# Prcessing Record 29 of Set 3 | worcester
# Prcessing Record 30 of Set 3 | louisbourg
# City not found. Skipping....
# Prcessing Record 31 of Set 3 | kiama
# Prcessing Record 32 of Set 3 | erenhot
# Prcessing Record 33 of Set 3 | honolulu
# Prcessing Record 34 of Set 3 | kavaratti
# Prcessing Record 35 of Set 3 | faanui
# Prcessing Record 36 of Set 3 | lagoa
# Prcessing Record 37 of Set 3 | portland
# Prcessing Record 38 of Set 3 | saint-philippe
# Prcessing Record 39 of Set 3 | dikson
# Prcessing Record 40 of Set 3 | worthington
# Prcessing Record 41 of Set 3 | kodiak
# Prcessing Record 42 of Set 3 | mys shmidta
# City not found. Skipping....
# Prcessing Record 43 of Set 3 | bengkulu
# Prcessing Record 44 of Set 3 | ahipara
# Prcessing Record 45 of Set 3 | vigrestad
# Prcessing Record 46 of Set 3 | kudahuvadhoo
# Prcessing Record 47 of Set 3 | bathsheba
# Prcessing Record 48 of Set 3 | pisco
# Prcessing Record 49 of Set 3 | dwarka
# Prcessing Record 50 of Set 3 | sansai
# City not found. Skipping....
# Prcessing Record 1 of Set 4 | esso
# Prcessing Record 2 of Set 4 | palauig
# Prcessing Record 3 of Set 4 | hambantota
# Prcessing Record 4 of Set 4 | general roca
# Prcessing Record 5 of Set 4 | talnakh
# Prcessing Record 6 of Set 4 | riyadh
# Prcessing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping....
# Prcessing Record 8 of Set 4 | vanimo
# Prcessing Record 9 of Set 4 | yumen
# Prcessing Record 10 of Set 4 | maldonado
# Prcessing Record 11 of Set 4 | progreso
# Prcessing Record 12 of Set 4 | lucea
# Prcessing Record 13 of Set 4 | luderitz
# Prcessing Record 14 of Set 4 | narsaq
# Prcessing Record 15 of Set 4 | midlothian
# Prcessing Record 16 of Set 4 | jujuy
# City not found. Skipping....
# Prcessing Record 17 of Set 4 | naze
# Prcessing Record 18 of Set 4 | nome
# Prcessing Record 19 of Set 4 | santander
# Prcessing Record 20 of Set 4 | uzumlu
# City not found. Skipping....
# Prcessing Record 21 of Set 4 | muravlenko
# Prcessing Record 22 of Set 4 | namibe
# Prcessing Record 23 of Set 4 | attawapiskat
# City not found. Skipping....
# Prcessing Record 24 of Set 4 | los llanos de aridane
# Prcessing Record 25 of Set 4 | palmer
# Prcessing Record 26 of Set 4 | isangel
# Prcessing Record 27 of Set 4 | bloomfield
# Prcessing Record 28 of Set 4 | tiksi
# Prcessing Record 29 of Set 4 | svetlaya
# Prcessing Record 30 of Set 4 | baruun-urt
# Prcessing Record 31 of Set 4 | nouadhibou
# Prcessing Record 32 of Set 4 | batticaloa
# Prcessing Record 33 of Set 4 | krasnokamensk
# Prcessing Record 34 of Set 4 | kutum
# Prcessing Record 35 of Set 4 | auki
# Prcessing Record 36 of Set 4 | severo-kurilsk
# Prcessing Record 37 of Set 4 | ust-kamchatsk
# City not found. Skipping....
# Prcessing Record 38 of Set 4 | rorvik
# Prcessing Record 39 of Set 4 | talaya
# Prcessing Record 40 of Set 4 | starozhilovo
# Prcessing Record 41 of Set 4 | san pedro
# Prcessing Record 42 of Set 4 | rio gallegos
# Prcessing Record 43 of Set 4 | taltal
# Prcessing Record 44 of Set 4 | krasnoselkup
# Prcessing Record 45 of Set 4 | rapid valley
# Prcessing Record 46 of Set 4 | bredasdorp
# Prcessing Record 47 of Set 4 | dawei
# Prcessing Record 48 of Set 4 | channel-port aux basques
# Prcessing Record 49 of Set 4 | christchurch
# Prcessing Record 50 of Set 4 | sao joao da barra
# Prcessing Record 1 of Set 5 | burkhala
# City not found. Skipping....
# Prcessing Record 2 of Set 5 | mabai
# Prcessing Record 3 of Set 5 | chumphon
# Prcessing Record 4 of Set 5 | san francisco
# Prcessing Record 5 of Set 5 | daitari
# Prcessing Record 6 of Set 5 | jinchang
# Prcessing Record 7 of Set 5 | sao jose de ribamar
# Prcessing Record 8 of Set 5 | katsuura
# Prcessing Record 9 of Set 5 | papar
# Prcessing Record 10 of Set 5 | praia da vitoria
# Prcessing Record 11 of Set 5 | tsihombe
# City not found. Skipping....
# Prcessing Record 12 of Set 5 | surt
# Prcessing Record 13 of Set 5 | vao
# Prcessing Record 14 of Set 5 | ostrovnoy
# Prcessing Record 15 of Set 5 | port-cartier
# Prcessing Record 16 of Set 5 | andrushivka
# Prcessing Record 17 of Set 5 | gannan
# Prcessing Record 18 of Set 5 | numan
# Prcessing Record 19 of Set 5 | korla
# Prcessing Record 20 of Set 5 | dalfsen
# Prcessing Record 21 of Set 5 | airai
# Prcessing Record 22 of Set 5 | belaya gora
# Prcessing Record 23 of Set 5 | qandala
# Prcessing Record 24 of Set 5 | east london
# Prcessing Record 25 of Set 5 | cabalitian
# Prcessing Record 26 of Set 5 | kassala
# Prcessing Record 27 of Set 5 | richards bay
# Prcessing Record 28 of Set 5 | tikapur
# Prcessing Record 29 of Set 5 | kloulklubed
# Prcessing Record 30 of Set 5 | bodaybo
# Prcessing Record 31 of Set 5 | bubaque
# Prcessing Record 32 of Set 5 | saint-pierre
# Prcessing Record 33 of Set 5 | kwinana
# Prcessing Record 34 of Set 5 | jutai
# Prcessing Record 35 of Set 5 | mao
# Prcessing Record 36 of Set 5 | rio cuarto
# Prcessing Record 37 of Set 5 | kahului
# Prcessing Record 38 of Set 5 | damietta
# Prcessing Record 39 of Set 5 | mackay
# Prcessing Record 40 of Set 5 | hasaki
# Prcessing Record 41 of Set 5 | paraiso
# Prcessing Record 42 of Set 5 | broken hill
# Prcessing Record 43 of Set 5 | qaanaaq
# Prcessing Record 44 of Set 5 | ampanihy
# Prcessing Record 45 of Set 5 | bar harbor
# Prcessing Record 46 of Set 5 | lavrentiya
# Prcessing Record 47 of Set 5 | verkhnevilyuysk
# Prcessing Record 48 of Set 5 | stornoway
# Prcessing Record 49 of Set 5 | constitucion
# Prcessing Record 50 of Set 5 | aketi
# Prcessing Record 1 of Set 6 | oranjemund
# Prcessing Record 2 of Set 6 | acarau
# Prcessing Record 3 of Set 6 | esperance
# Prcessing Record 4 of Set 6 | aklavik
# Prcessing Record 5 of Set 6 | rovnoye
# Prcessing Record 6 of Set 6 | ibra
# Prcessing Record 7 of Set 6 | ornes
# Prcessing Record 8 of Set 6 | chuy
# Prcessing Record 9 of Set 6 | saint george
# Prcessing Record 10 of Set 6 | redmond
# Prcessing Record 11 of Set 6 | kathu
# Prcessing Record 12 of Set 6 | shimoda
# Prcessing Record 13 of Set 6 | solnechnyy
# Prcessing Record 14 of Set 6 | saint-joseph
# Prcessing Record 15 of Set 6 | lolua
# City not found. Skipping....
# Prcessing Record 16 of Set 6 | severodvinsk
# Prcessing Record 17 of Set 6 | angoche
# Prcessing Record 18 of Set 6 | cayenne
# Prcessing Record 19 of Set 6 | kuche
# City not found. Skipping....
# Prcessing Record 20 of Set 6 | cihuatlan
# Prcessing Record 21 of Set 6 | pangnirtung
# Prcessing Record 22 of Set 6 | faya
# Prcessing Record 23 of Set 6 | mahebourg
# Prcessing Record 24 of Set 6 | muisne
# Prcessing Record 25 of Set 6 | zeya
# Prcessing Record 26 of Set 6 | ozgon
# City not found. Skipping....
# Prcessing Record 27 of Set 6 | champerico
# Prcessing Record 28 of Set 6 | marawi
# Prcessing Record 29 of Set 6 | itarema
# Prcessing Record 30 of Set 6 | coahuayana
# Prcessing Record 31 of Set 6 | grand gaube
# Prcessing Record 32 of Set 6 | tsaratanana
# Prcessing Record 33 of Set 6 | houma
# Prcessing Record 34 of Set 6 | tecoanapa
# Prcessing Record 35 of Set 6 | provideniya
# Prcessing Record 36 of Set 6 | santa catarina de tepehuanes
# Prcessing Record 37 of Set 6 | tessaoua
# Prcessing Record 38 of Set 6 | gerash
# Prcessing Record 39 of Set 6 | norman wells
# Prcessing Record 40 of Set 6 | sakakah
# Prcessing Record 41 of Set 6 | gizo
# Prcessing Record 42 of Set 6 | shediac
# Prcessing Record 43 of Set 6 | winslow
# Prcessing Record 44 of Set 6 | vega de alatorre
# Prcessing Record 45 of Set 6 | cedar city
# Prcessing Record 46 of Set 6 | masindi
# Prcessing Record 47 of Set 6 | raudeberg
# Prcessing Record 48 of Set 6 | povoa de varzim
# Prcessing Record 49 of Set 6 | araouane
# Prcessing Record 50 of Set 6 | leh
# Prcessing Record 1 of Set 7 | pemberton
# Prcessing Record 2 of Set 7 | teguise
# Prcessing Record 3 of Set 7 | sentyabrskiy
# City not found. Skipping....
# Prcessing Record 4 of Set 7 | sao miguel do araguaia
# Prcessing Record 5 of Set 7 | marzuq
# Prcessing Record 6 of Set 7 | miranorte
# City not found. Skipping....
# Prcessing Record 7 of Set 7 | tajumulco
# Prcessing Record 8 of Set 7 | vanavara
# Prcessing Record 9 of Set 7 | ulaanbaatar
# Prcessing Record 10 of Set 7 | saint john
# Prcessing Record 11 of Set 7 | sosnovo-ozerskoye
# Prcessing Record 12 of Set 7 | manta
# Prcessing Record 13 of Set 7 | khovu-aksy
# Prcessing Record 14 of Set 7 | crossville
# Prcessing Record 15 of Set 7 | arlit
# Prcessing Record 16 of Set 7 | morro bay
# Prcessing Record 17 of Set 7 | klaebu
# Prcessing Record 18 of Set 7 | tagusao
# Prcessing Record 19 of Set 7 | ribeira brava
# Prcessing Record 20 of Set 7 | ingham
# Prcessing Record 21 of Set 7 | kupang
# Prcessing Record 22 of Set 7 | nishihara
# Prcessing Record 23 of Set 7 | geraldton
# Prcessing Record 24 of Set 7 | tiznit
# Prcessing Record 25 of Set 7 | pochutla
# Prcessing Record 26 of Set 7 | duluth
# Prcessing Record 27 of Set 7 | kamenskoye
# City not found. Skipping....
# Prcessing Record 28 of Set 7 | voyvozh
# Prcessing Record 29 of Set 7 | tidore
# City not found. Skipping....
# Prcessing Record 30 of Set 7 | buala
# Prcessing Record 31 of Set 7 | ahuimanu
# Prcessing Record 32 of Set 7 | guder
# Prcessing Record 33 of Set 7 | sabratah
# Prcessing Record 34 of Set 7 | marshall
# Prcessing Record 35 of Set 7 | bonthe
# Prcessing Record 36 of Set 7 | dunedin
# Prcessing Record 37 of Set 7 | malegaon
# Prcessing Record 38 of Set 7 | batagay-alyta
# Prcessing Record 39 of Set 7 | walvis bay
# Prcessing Record 40 of Set 7 | kirkenaer
# Prcessing Record 41 of Set 7 | mujiayingzi
# Prcessing Record 42 of Set 7 | warrnambool
# Prcessing Record 43 of Set 7 | jiamusi
# Prcessing Record 44 of Set 7 | xianyang
# Prcessing Record 45 of Set 7 | bira
# Prcessing Record 46 of Set 7 | araceli
# Prcessing Record 47 of Set 7 | belogorsk
# Prcessing Record 48 of Set 7 | rawson
# Prcessing Record 49 of Set 7 | saldanha
# Prcessing Record 50 of Set 7 | baza
# Prcessing Record 1 of Set 8 | saint anthony
# Prcessing Record 2 of Set 8 | valmiera
# Prcessing Record 3 of Set 8 | sorvag
# City not found. Skipping....
# Prcessing Record 4 of Set 8 | jhanjharpur
# Prcessing Record 5 of Set 8 | nioro
# Prcessing Record 6 of Set 8 | bichura
# Prcessing Record 7 of Set 8 | glendive
# Prcessing Record 8 of Set 8 | dali
# Prcessing Record 9 of Set 8 | flin flon
# Prcessing Record 10 of Set 8 | lasa
# Prcessing Record 11 of Set 8 | kapit
# Prcessing Record 12 of Set 8 | norrtalje
# Prcessing Record 13 of Set 8 | karaul
# City not found. Skipping....
# Prcessing Record 14 of Set 8 | santa barbara
# Prcessing Record 15 of Set 8 | tabou
# Prcessing Record 16 of Set 8 | marovoay
# Prcessing Record 17 of Set 8 | baykit
# Prcessing Record 18 of Set 8 | terrace
# Prcessing Record 19 of Set 8 | matipo
# Prcessing Record 20 of Set 8 | henties bay
# Prcessing Record 21 of Set 8 | fevralsk
# City not found. Skipping....
# Prcessing Record 22 of Set 8 | moyobamba
# Prcessing Record 23 of Set 8 | amderma
# City not found. Skipping....
# Prcessing Record 24 of Set 8 | olsztyn
# Prcessing Record 25 of Set 8 | leshukonskoye
# Prcessing Record 26 of Set 8 | laguna
# Prcessing Record 27 of Set 8 | xiongyue
# Prcessing Record 28 of Set 8 | aktash
# Prcessing Record 29 of Set 8 | belen
# Prcessing Record 30 of Set 8 | baghmara
# Prcessing Record 31 of Set 8 | andenes
# Prcessing Record 32 of Set 8 | takoradi
# Prcessing Record 33 of Set 8 | coolum beach
# Prcessing Record 34 of Set 8 | benjamin aceval
# Prcessing Record 35 of Set 8 | baniyas
# Prcessing Record 36 of Set 8 | lorengau
# Prcessing Record 37 of Set 8 | lisala
# Prcessing Record 38 of Set 8 | gazojak
# Prcessing Record 39 of Set 8 | bambari
# Prcessing Record 40 of Set 8 | aras
# Prcessing Record 41 of Set 8 | artyk
# City not found. Skipping....
# Prcessing Record 42 of Set 8 | bouna
# Prcessing Record 43 of Set 8 | ouesso
# Prcessing Record 44 of Set 8 | mount gambier
# Prcessing Record 45 of Set 8 | saryshagan
# City not found. Skipping....
# Prcessing Record 46 of Set 8 | singkawang
# Prcessing Record 47 of Set 8 | lodwar
# Prcessing Record 48 of Set 8 | yangjiang
# Prcessing Record 49 of Set 8 | valparaiso
# Prcessing Record 50 of Set 8 | kununurra
# Prcessing Record 1 of Set 9 | boa vista
# Prcessing Record 2 of Set 9 | victoria point
# Prcessing Record 3 of Set 9 | timaru
# Prcessing Record 4 of Set 9 | dakar
# Prcessing Record 5 of Set 9 | zonguldak
# Prcessing Record 6 of Set 9 | reconquista
# Prcessing Record 7 of Set 9 | andijon
# Prcessing Record 8 of Set 9 | herat
# Prcessing Record 9 of Set 9 | kenai
# Prcessing Record 10 of Set 9 | ystad
# Prcessing Record 11 of Set 9 | te anau
# Prcessing Record 12 of Set 9 | voh
# Prcessing Record 13 of Set 9 | tubuala
# Prcessing Record 14 of Set 9 | touros
# Prcessing Record 15 of Set 9 | carauari
# Prcessing Record 16 of Set 9 | moron
# Prcessing Record 17 of Set 9 | plymouth
# Prcessing Record 18 of Set 9 | yar-sale
# Prcessing Record 19 of Set 9 | nenjiang
# Prcessing Record 20 of Set 9 | portlethen
# Prcessing Record 21 of Set 9 | venado tuerto
# Prcessing Record 22 of Set 9 | alofi
# Prcessing Record 23 of Set 9 | sanmenxia
# Prcessing Record 24 of Set 9 | porbandar
# Prcessing Record 25 of Set 9 | hamilton
# Prcessing Record 26 of Set 9 | savannah bight
# Prcessing Record 27 of Set 9 | yialos
# City not found. Skipping....
# Prcessing Record 28 of Set 9 | victoria
# Prcessing Record 29 of Set 9 | gazanjyk
# Prcessing Record 30 of Set 9 | russell
# Prcessing Record 31 of Set 9 | trofors
# Prcessing Record 32 of Set 9 | rockland
# Prcessing Record 33 of Set 9 | gorom-gorom
# Prcessing Record 34 of Set 9 | billings
# Prcessing Record 35 of Set 9 | merauke
# Prcessing Record 36 of Set 9 | youkounkoun
# Prcessing Record 37 of Set 9 | goba
# Prcessing Record 38 of Set 9 | erdenet
# Prcessing Record 39 of Set 9 | coihaique
# Prcessing Record 40 of Set 9 | najran
# Prcessing Record 41 of Set 9 | santa ines
# Prcessing Record 42 of Set 9 | srednekolymsk
# Prcessing Record 43 of Set 9 | ponta do sol
# Prcessing Record 44 of Set 9 | quatre cocos
# Prcessing Record 45 of Set 9 | oktyabrskoye
# Prcessing Record 46 of Set 9 | gardner
# Prcessing Record 47 of Set 9 | sorsk
# Prcessing Record 48 of Set 9 | lagunas
# Prcessing Record 49 of Set 9 | synya
# Prcessing Record 50 of Set 9 | polunochnoye
# Prcessing Record 1 of Set 10 | berlevag
# Prcessing Record 2 of Set 10 | nguruka
# Prcessing Record 3 of Set 10 | cumaribo
# City not found. Skipping....
# Prcessing Record 4 of Set 10 | tawang
# Prcessing Record 5 of Set 10 | kandrian
# Prcessing Record 6 of Set 10 | chake chake
# Prcessing Record 7 of Set 10 | phan thiet
# Prcessing Record 8 of Set 10 | sibolga
# Prcessing Record 9 of Set 10 | charlestown
# Prcessing Record 10 of Set 10 | aasiaat
# Prcessing Record 11 of Set 10 | khandyga
# Prcessing Record 12 of Set 10 | santa rosalia
# Prcessing Record 13 of Set 10 | sitka
# Prcessing Record 14 of Set 10 | neuquen
# Prcessing Record 15 of Set 10 | uruzgan
# Prcessing Record 16 of Set 10 | orange cove
# Prcessing Record 17 of Set 10 | carballo
# Prcessing Record 18 of Set 10 | emba
# Prcessing Record 19 of Set 10 | umba
# Prcessing Record 20 of Set 10 | ambovombe
# Prcessing Record 21 of Set 10 | ust-kut
# Prcessing Record 22 of Set 10 | phek
# Prcessing Record 23 of Set 10 | mbour
# Prcessing Record 24 of Set 10 | darhan
# Prcessing Record 25 of Set 10 | avera
# Prcessing Record 26 of Set 10 | tapaua
# City not found. Skipping....
# Prcessing Record 27 of Set 10 | mendota
# Prcessing Record 28 of Set 10 | puerto escondido
# Prcessing Record 29 of Set 10 | chapleau
# Prcessing Record 30 of Set 10 | nuuk
# Prcessing Record 31 of Set 10 | narasannapeta
# Prcessing Record 32 of Set 10 | asino
# Prcessing Record 33 of Set 10 | rocha
# Prcessing Record 34 of Set 10 | guajara-mirim
# City not found. Skipping....
# Prcessing Record 35 of Set 10 | bila
# Prcessing Record 36 of Set 10 | tezu
# Prcessing Record 37 of Set 10 | grinnell
# Prcessing Record 38 of Set 10 | san cristobal
# Prcessing Record 39 of Set 10 | tucuru
# Prcessing Record 40 of Set 10 | poum
# Prcessing Record 41 of Set 10 | yakeshi
# Prcessing Record 42 of Set 10 | ajdabiya
# Prcessing Record 43 of Set 10 | iqaluit
# Prcessing Record 44 of Set 10 | middlebury
# Prcessing Record 45 of Set 10 | maghama
# City not found. Skipping....
# Prcessing Record 46 of Set 10 | ust-nera
# Prcessing Record 47 of Set 10 | ericeira
# Prcessing Record 48 of Set 10 | ozernovskiy
# Prcessing Record 49 of Set 10 | jalu
# Prcessing Record 50 of Set 10 | souillac
# Prcessing Record 1 of Set 11 | sola
# Prcessing Record 2 of Set 11 | umzimvubu
# City not found. Skipping....
# Prcessing Record 3 of Set 11 | dolbeau
# City not found. Skipping....
# Prcessing Record 4 of Set 11 | wladyslawowo
# Prcessing Record 5 of Set 11 | wembley
# Prcessing Record 6 of Set 11 | acapulco
# Prcessing Record 7 of Set 11 | kapuskasing
# Prcessing Record 8 of Set 11 | moroto
# Prcessing Record 9 of Set 11 | kifri
# Prcessing Record 10 of Set 11 | sidhi
# Prcessing Record 11 of Set 11 | muros
# Prcessing Record 12 of Set 11 | grand baie
# Prcessing Record 13 of Set 11 | yukhnov
# Prcessing Record 14 of Set 11 | satitoa
# City not found. Skipping....
# Prcessing Record 15 of Set 11 | comodoro rivadavia
# Prcessing Record 16 of Set 11 | makakilo city
# Prcessing Record 17 of Set 11 | qui nhon
# Prcessing Record 18 of Set 11 | guerrero negro
# Prcessing Record 19 of Set 11 | caravelas
# Prcessing Record 20 of Set 11 | port lincoln
# Prcessing Record 21 of Set 11 | bemidji
# Prcessing Record 22 of Set 11 | mandan
# Prcessing Record 23 of Set 11 | bossier city
# Prcessing Record 24 of Set 11 | katangli
# Prcessing Record 25 of Set 11 | verkh-usugli
# Prcessing Record 26 of Set 11 | midland
# Prcessing Record 27 of Set 11 | bilma
# Prcessing Record 28 of Set 11 | fontanka
# Prcessing Record 29 of Set 11 | alegrete
# Prcessing Record 30 of Set 11 | praia
# Prcessing Record 31 of Set 11 | le port
# Prcessing Record 32 of Set 11 | mangrol
# Prcessing Record 33 of Set 11 | aksay
# Prcessing Record 34 of Set 11 | bolungarvik
# City not found. Skipping....
# Prcessing Record 35 of Set 11 | kungurtug
# Prcessing Record 36 of Set 11 | gornopravdinsk
# Prcessing Record 37 of Set 11 | kibala
# Prcessing Record 38 of Set 11 | gamba
# Prcessing Record 39 of Set 11 | toliary
# City not found. Skipping....
# Prcessing Record 40 of Set 11 | seabra
# Prcessing Record 41 of Set 11 | bayan
# Prcessing Record 42 of Set 11 | santiago de cao
# Prcessing Record 43 of Set 11 | jinchengjiang
# City not found. Skipping....
# Prcessing Record 44 of Set 11 | zaranj
# Prcessing Record 45 of Set 11 | revda
# Prcessing Record 46 of Set 11 | port hedland
# Prcessing Record 47 of Set 11 | tabiauea
# City not found. Skipping....
# Prcessing Record 48 of Set 11 | umm kaddadah
# Prcessing Record 49 of Set 11 | hapur
# Prcessing Record 50 of Set 11 | padang
# Prcessing Record 1 of Set 12 | san jose de guanipa
# Prcessing Record 2 of Set 12 | vostok
# Prcessing Record 3 of Set 12 | maykopskoye
# Prcessing Record 4 of Set 12 | asyut
# Prcessing Record 5 of Set 12 | husavik
# Prcessing Record 6 of Set 12 | tula
# Prcessing Record 7 of Set 12 | sturgeon bay
# Prcessing Record 8 of Set 12 | svetlogorsk
# Prcessing Record 9 of Set 12 | leningradskiy
# Prcessing Record 10 of Set 12 | udachnyy
# Prcessing Record 11 of Set 12 | kattivakkam
# Prcessing Record 12 of Set 12 | sisimiut
# Prcessing Record 13 of Set 12 | buchanan
# Prcessing Record 14 of Set 12 | gweta
# Prcessing Record 15 of Set 12 | launceston
# Prcessing Record 16 of Set 12 | ayutla
# Prcessing Record 17 of Set 12 | bara
# Prcessing Record 18 of Set 12 | marsabit
# Prcessing Record 19 of Set 12 | linqiong
# Prcessing Record 20 of Set 12 | clyde river
# Prcessing Record 21 of Set 12 | dombarovskiy
# Prcessing Record 22 of Set 12 | tutoia
# Prcessing Record 23 of Set 12 | zhanakorgan
# Prcessing Record 24 of Set 12 | mazatlan
# Prcessing Record 25 of Set 12 | nabire
# Prcessing Record 26 of Set 12 | paez
# Prcessing Record 27 of Set 12 | brae
# Prcessing Record 28 of Set 12 | lima
# Prcessing Record 29 of Set 12 | sorong
# Prcessing Record 30 of Set 12 | scandiano
# Prcessing Record 31 of Set 12 | jerecuaro
# Prcessing Record 32 of Set 12 | binzhou
# Prcessing Record 33 of Set 12 | klyuchevskiy
# Prcessing Record 34 of Set 12 | karratha
# Prcessing Record 35 of Set 12 | laramie
# Prcessing Record 36 of Set 12 | beringovskiy
# Prcessing Record 37 of Set 12 | broome
# Prcessing Record 38 of Set 12 | maine-soroa
# Prcessing Record 39 of Set 12 | grindavik
# Prcessing Record 40 of Set 12 | tunduru
# City not found. Skipping....
# Prcessing Record 41 of Set 12 | omalur
# Prcessing Record 42 of Set 12 | astoria
# Prcessing Record 43 of Set 12 | honiara
# Prcessing Record 44 of Set 12 | boyolangu
# Prcessing Record 45 of Set 12 | sobolevo
# Prcessing Record 46 of Set 12 | polewali
# Prcessing Record 47 of Set 12 | dengzhou
# Prcessing Record 48 of Set 12 | tambopata
# Prcessing Record 49 of Set 12 | mocuba
# Prcessing Record 50 of Set 12 | san jose de buan
# Prcessing Record 1 of Set 13 | lubumbashi
# Prcessing Record 2 of Set 13 | safaga
# Prcessing Record 3 of Set 13 | da lat
# Prcessing Record 4 of Set 13 | kurchum
# Prcessing Record 5 of Set 13 | tsentralnyy
# City not found. Skipping....
# Prcessing Record 6 of Set 13 | virtsu
# Prcessing Record 7 of Set 13 | salinopolis
# Prcessing Record 8 of Set 13 | windhoek
# Prcessing Record 9 of Set 13 | port blair
# Prcessing Record 10 of Set 13 | oktyabrskiy
# Prcessing Record 11 of Set 13 | farsund
# Prcessing Record 12 of Set 13 | ambilobe
# Prcessing Record 13 of Set 13 | nizwa
# Prcessing Record 14 of Set 13 | sikar
# Prcessing Record 15 of Set 13 | kroya
# Prcessing Record 16 of Set 13 | arcata
# Prcessing Record 17 of Set 13 | ondjiva
# Prcessing Record 18 of Set 13 | karmana
# City not found. Skipping....
# Prcessing Record 19 of Set 13 | mabaruma
# Prcessing Record 20 of Set 13 | am timan
# Prcessing Record 21 of Set 13 | nemuro
# Prcessing Record 22 of Set 13 | skjervoy
# Prcessing Record 23 of Set 13 | ola
# Prcessing Record 24 of Set 13 | vaasa
# Prcessing Record 25 of Set 13 | west bay
# Prcessing Record 26 of Set 13 | foam lake
# Prcessing Record 27 of Set 13 | ixtapa
# Prcessing Record 28 of Set 13 | manica
# Prcessing Record 29 of Set 13 | bend
# Prcessing Record 30 of Set 13 | morondava
# Prcessing Record 31 of Set 13 | septemvri
# Prcessing Record 32 of Set 13 | callaway
# Prcessing Record 33 of Set 13 | porto seguro
# Prcessing Record 34 of Set 13 | cockburn town
# Prcessing Record 35 of Set 13 | verdun
# Prcessing Record 36 of Set 13 | saint-honore
# Prcessing Record 37 of Set 13 | horb
# Prcessing Record 38 of Set 13 | valdivia
# Prcessing Record 39 of Set 13 | sabha
# Prcessing Record 40 of Set 13 | jibuti
# Prcessing Record 41 of Set 13 | matata
# Prcessing Record 42 of Set 13 | taunggyi
# Prcessing Record 43 of Set 13 | mehran
# Prcessing Record 44 of Set 13 | gus-zheleznyy
# Prcessing Record 45 of Set 13 | san rafael del sur
# Prcessing Record 46 of Set 13 | tessalit
# Prcessing Record 47 of Set 13 | vladimiro-aleksandrovskoye
# Prcessing Record 48 of Set 13 | mae ramat
# Prcessing Record 49 of Set 13 | eureka
# Prcessing Record 50 of Set 13 | nantucket
# Prcessing Record 1 of Set 14 | flinders
# Prcessing Record 2 of Set 14 | mokhsogollokh
# Prcessing Record 3 of Set 14 | fairview
# Prcessing Record 4 of Set 14 | kazalinsk
# City not found. Skipping....
# Prcessing Record 5 of Set 14 | tay ninh
# Prcessing Record 6 of Set 14 | atar
# Prcessing Record 7 of Set 14 | la romana
# Prcessing Record 8 of Set 14 | sinnamary
# Prcessing Record 9 of Set 14 | agadir
# Prcessing Record 10 of Set 14 | ascension
# Prcessing Record 11 of Set 14 | lubu
# Prcessing Record 12 of Set 14 | ashqelon
# Prcessing Record 13 of Set 14 | diego de almagro
# Prcessing Record 14 of Set 14 | elko
# Prcessing Record 15 of Set 14 | kashi
# Prcessing Record 16 of Set 14 | choix
# Prcessing Record 17 of Set 14 | tumannyy
# City not found. Skipping....
# Prcessing Record 18 of Set 14 | itoman
# Prcessing Record 19 of Set 14 | namatanai
# Prcessing Record 20 of Set 14 | ures
# Prcessing Record 21 of Set 14 | olafsvik
# Prcessing Record 22 of Set 14 | ranghulu
# Prcessing Record 23 of Set 14 | jacareacanga
# Prcessing Record 24 of Set 14 | kaseda
# Prcessing Record 25 of Set 14 | alappuzha
# Prcessing Record 26 of Set 14 | lagos
# Prcessing Record 27 of Set 14 | plaster rock
# Prcessing Record 28 of Set 14 | preston
# Prcessing Record 29 of Set 14 | boksitogorsk
# Prcessing Record 30 of Set 14 | san jeronimo
# Prcessing Record 31 of Set 14 | aste
# Prcessing Record 32 of Set 14 | chadiza
# Prcessing Record 33 of Set 14 | bagado
# Prcessing Record 34 of Set 14 | sujawal
# City not found. Skipping....
# Prcessing Record 35 of Set 14 | krasnoarmeysk
# Prcessing Record 36 of Set 14 | grootfontein
# Prcessing Record 37 of Set 14 | cubatao
# Prcessing Record 38 of Set 14 | tupik
# Prcessing Record 39 of Set 14 | tsabong
# Prcessing Record 40 of Set 14 | cape elizabeth
# City not found. Skipping....
# Prcessing Record 41 of Set 14 | sal rei
# Prcessing Record 42 of Set 14 | karamay
# City not found. Skipping....
# Prcessing Record 43 of Set 14 | karlskrona
# Prcessing Record 44 of Set 14 | santa catalina
# Prcessing Record 45 of Set 14 | metlaltoyuca
# Prcessing Record 46 of Set 14 | kirakira
# Prcessing Record 47 of Set 14 | mityana
# Prcessing Record 48 of Set 14 | belmonte
# Prcessing Record 49 of Set 14 | zyryanka
# Prcessing Record 50 of Set 14 | loralai
# Prcessing Record 1 of Set 15 | roshchino
# Prcessing Record 2 of Set 15 | denham springs
# Prcessing Record 3 of Set 15 | conde
# Prcessing Record 4 of Set 15 | westport
# Prcessing Record 5 of Set 15 | winton
# Prcessing Record 6 of Set 15 | skalat
# Prcessing Record 7 of Set 15 | caraballeda
# Prcessing Record 8 of Set 15 | shenjiamen
# Prcessing Record 9 of Set 15 | la ligua
# Prcessing Record 10 of Set 15 | oda
# Prcessing Record 11 of Set 15 | ndende
# Prcessing Record 12 of Set 15 | panormos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Creating the city data dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pevek      RU  69.7008  170.3133     33.33        83          21
# 1       Atuona      PF  -9.8000 -139.0333     77.86        72           2
# 2  Tuktoyaktuk      CA  69.4541 -133.0374     57.20        44          40
# 3      Mataura      NZ -46.1927  168.8643     36.48        92          38
# 4       Hobart      AU -42.8794  147.3294     43.27        94          20
# 5    Hithadhoo      MV  -0.6000   73.0833     81.18        76         100
# 6        Roald      NO  62.5833    6.1333     58.15        94          75
# 7   Nelson Bay      AU -32.7167  152.1500     51.01        93           4
# 8        Basco      PH  20.4487  121.9702     85.55        74          87
# 9        Vaini      TO -21.2000 -175.2000     77.16        83          40
#
#    Wind Speed Current Description
# 0        5.82          few clouds
# 1       19.89           clear sky
# 2       13.80    scattered clouds
# 3        2.24    scattered clouds
# 4        5.75          few clouds
# 5       10.09          light rain
# 6        3.44       broken clouds
# 7       12.84           clear sky
# 8       12.35     overcast clouds
# 9        9.22    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_data into a csv 
city_data_df.to_csv(output_data_file,index_label = "City ID")
